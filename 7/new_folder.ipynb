# %%
from bigtree import BaseNode,Node, print_tree, find,find_name,find_names, findall,find_attr

# %%
class FileNode(Node):

    # def __init__(self, name: str, size: int = 0, **kwargs):
    #     super().__init__(name, **kwargs)
    #     self._size = size
        

    def __init__(self,name:str,type='',size=0,**kwargs):
        super().__init__(name, **kwargs)
        self._type=type
        self._size=size   
        #self.id=self.name+next(self.ancestors).name

    @property
    def type(self):
        return self._type
    
    @property
    def size(self):
        if self.is_leaf:
            return self._size
        total=sum([child.size for child in self.children])

        return total #if total<=100000 and self._type == 'dir' else 0

# %%
def read_Treedata(file='sample.txt'):
    
    
    root=FileNode(name='root',type='dir')
    current=root
    
    listing=False
    with open(file) as f:
        lines = f.readlines()
    
        for line in lines:
            
            if line == '\n':
                break
                
            else:
                line=line.strip()
                print(line,len(line),current,'last:',line[-1])
                if line=='$ cd /':
                    print('root node')
                    current=root
                    
                    listing=False
                    continue
                
                # check of $ls
                elif line=='$ ls':
                    print('listing')
                    listing=True
                #  # go to parent node   
                elif line=='$ cd ..':
                    
                    print('go to parent')
                    print('current',current)
                    current=current.parent

                    listing=False

                # move to subdirectory  
                elif (line[:4]=='$ cd' and line[-2:]!='..' and len(line)>=6):
                    print('--node change')
                    new_node_name=line.split(' ')[2]
                    # checks if parent exists
                    curr=current
                    if current.parent is not None:
                        current=find(root,lambda node:node.parent==curr and node.name==new_node_name)
                    else:
                        current=find(root,lambda node:node.parent==root and node.name==new_node_name)
                    print('new curr:',current)
            
                    listing=False
                else:
                    print('list children')
                    if listing is True:
                        file_spec=line.split(' ')
                            
                        
                        if line[:4]!='dir ':
                            file_name,size=file_spec[1],int(file_spec[0])
                            type='file'
                        else:
                            size=0
                            file_name=file_spec[1]
                            type='dir'

                        print(current,"file_name:",file_name,'size:',size)
                            
                        # node_loc=find(root,lambda node:node.name==file_name)
                        # if node_loc==None:
                        #     print('---new node')
                        #     temp=FileNode(file_name,size=size,type=type,parent=current)
                        #     print(temp)
                        # elif node_loc!=None and next(node_loc.ancestors) is current:
                        #     print('---new node')
                        #     temp=FileNode(file_name,size=size,type=type,parent=current)
                        #     print(temp)
                        temp=FileNode(file_name,size=size,type=type,parent=current)

                    else: continue

    

    #print_tree(root,attr_list=['size'])
    return root

# %%
tree=read_Treedata()
# Out:
# $ cd / 6 FileNode(/root, ) last: /
# root node
# $ ls 4 FileNode(/root, ) last: s
# listing
# dir a 5 FileNode(/root, ) last: a
# list children
# FileNode(/root, ) file_name: a size: 0
# 14848514 b.txt 14 FileNode(/root, ) last: t
# list children
# FileNode(/root, ) file_name: b.txt size: 14848514
# 8504156 c.dat 13 FileNode(/root, ) last: t
# list children
# FileNode(/root, ) file_name: c.dat size: 8504156
# dir d 5 FileNode(/root, ) last: d
# list children
# FileNode(/root, ) file_name: d size: 0
# $ cd a 6 FileNode(/root, ) last: a
# --node change
# new curr: FileNode(/root/a, )
# $ ls 4 FileNode(/root/a, ) last: s
# listing
# dir e 5 FileNode(/root/a, ) last: e
# list children
# FileNode(/root/a, ) file_name: e size: 0
# 29116 f 7 FileNode(/root/a, ) last: f
# list children
# FileNode(/root/a, ) file_name: f size: 29116
# 2557 g 6 FileNode(/root/a, ) last: g
# list children
# FileNode(/root/a, ) file_name: g size: 2557
# 62596 h.lst 11 FileNode(/root/a, ) last: t
# list children
# FileNode(/root/a, ) file_name: h.lst size: 62596
# $ cd e 6 FileNode(/root/a, ) last: e
# --node change
# new curr: FileNode(/root/a/e, )
# $ ls 4 FileNode(/root/a/e, ) last: s
# listing
# 584 i 5 FileNode(/root/a/e, ) last: i
# list children
# FileNode(/root/a/e, ) file_name: i size: 584
# $ cd .. 7 FileNode(/root/a/e, ) last: .
# go to parent
# current FileNode(/root/a/e, )
# $ cd .. 7 FileNode(/root/a, ) last: .
# go to parent
# current FileNode(/root/a, )
# $ cd d 6 FileNode(/root, ) last: d
# --node change
# new curr: FileNode(/root/d, )
# $ ls 4 FileNode(/root/d, ) last: s
# listing
# 4060174 j 9 FileNode(/root/d, ) last: j
# list children
# FileNode(/root/d, ) file_name: j size: 4060174
# 8033020 d.log 13 FileNode(/root/d, ) last: g
# list children
# FileNode(/root/d, ) file_name: d.log size: 8033020
# 5626152 d.ext 13 FileNode(/root/d, ) last: t
# list children
# FileNode(/root/d, ) file_name: d.ext size: 5626152
# 7214296 k 9 FileNode(/root/d, ) last: k
# list children
# FileNode(/root/d, ) file_name: k size: 7214296

# %%
print_tree(tree,attr_list=['size'])
# Out:
# root [size=48381165]
# ├── a [size=94853]
# │   ├── e [size=584]
# │   │   └── i [size=584]
# │   ├── f [size=29116]
# │   ├── g [size=2557]
# │   └── h.lst [size=62596]
# ├── b.txt [size=14848514]
# ├── c.dat [size=8504156]
# └── d [size=24933642]
#     ├── j [size=4060174]
#     ├── d.log [size=8033020]
#     ├── d.ext [size=5626152]
#     └── k [size=7214296]

# %%
nodes=findall(tree,lambda node:node.size<=100000 and node.type=='dir')

# %%
arr=[node.size for node in nodes]
arr
# Out:
# [94853, 584]

# %%
import subarray

subarray.findMaxSubarraySum(arr,len(arr),100000)
# Out:
# 95437

# %%
tree2 = read_Treedata(file='data.txt')
# Out:
# $ cd / 6 FileNode(/root, ) last: /
# root node
# $ ls 4 FileNode(/root, ) last: s
# listing
# dir jmtrrrp 11 FileNode(/root, ) last: p
# list children
# FileNode(/root, ) file_name: jmtrrrp size: 0
# dir jssnn 9 FileNode(/root, ) last: n
# list children
# FileNode(/root, ) file_name: jssnn size: 0
# dir lbrmb 9 FileNode(/root, ) last: b
# list children
# FileNode(/root, ) file_name: lbrmb size: 0
# 11968 pcccp 11 FileNode(/root, ) last: p
# list children
# FileNode(/root, ) file_name: pcccp size: 11968
# $ cd jmtrrrp 12 FileNode(/root, ) last: p
# --node change
# new curr: FileNode(/root/jmtrrrp, )
# $ ls 4 FileNode(/root/jmtrrrp, ) last: s
# listing
# 77968 chq.jvb 13 FileNode(/root/jmtrrrp, ) last: b
# list children
# FileNode(/root/jmtrrrp, ) file_name: chq.jvb size: 77968
# dir fmgsql 10 FileNode(/root/jmtrrrp, ) last: l
# list children
# FileNode(/root/jmtrrrp, ) file_name: fmgsql size: 0
# $ cd fmgsql 11 FileNode(/root/jmtrrrp, ) last: l
# --node change
# new curr: FileNode(/root/jmtrrrp/fmgsql, )
# $ ls 4 FileNode(/root/jmtrrrp/fmgsql, ) last: s
# listing
# dir dbnsfp 10 FileNode(/root/jmtrrrp/fmgsql, ) last: p
# list children
# FileNode(/root/jmtrrrp/fmgsql, ) file_name: dbnsfp size: 0
# dir vvp 7 FileNode(/root/jmtrrrp/fmgsql, ) last: p
# list children
# FileNode(/root/jmtrrrp/fmgsql, ) file_name: vvp size: 0
# $ cd dbnsfp 11 FileNode(/root/jmtrrrp/fmgsql, ) last: p
# --node change
# new curr: FileNode(/root/jmtrrrp/fmgsql/dbnsfp, )
# $ ls 4 FileNode(/root/jmtrrrp/fmgsql/dbnsfp, ) last: s
# listing
# 51021 crlq.lrj 14 FileNode(/root/jmtrrrp/fmgsql/dbnsfp, ) last: j
# list children
# FileNode(/root/jmtrrrp/fmgsql/dbnsfp, ) file_name: crlq.lrj size: 51021
# 186829 dhcrzvbr.wmn 19 FileNode(/root/jmtrrrp/fmgsql/dbnsfp, ) last: n
# list children
# FileNode(/root/jmtrrrp/fmgsql/dbnsfp, ) file_name: dhcrzvbr.wmn size: 186829
# 16232 fvhn.fqm 14 FileNode(/root/jmtrrrp/fmgsql/dbnsfp, ) last: m
# list children
# FileNode(/root/jmtrrrp/fmgsql/dbnsfp, ) file_name: fvhn.fqm size: 16232
# 54150 qpbqqj.rpg 16 FileNode(/root/jmtrrrp/fmgsql/dbnsfp, ) last: g
# list children
# FileNode(/root/jmtrrrp/fmgsql/dbnsfp, ) file_name: qpbqqj.rpg size: 54150
# $ cd .. 7 FileNode(/root/jmtrrrp/fmgsql/dbnsfp, ) last: .
# go to parent
# current FileNode(/root/jmtrrrp/fmgsql/dbnsfp, )
# $ cd vvp 8 FileNode(/root/jmtrrrp/fmgsql, ) last: p
# --node change
# new curr: FileNode(/root/jmtrrrp/fmgsql/vvp, )
# $ ls 4 FileNode(/root/jmtrrrp/fmgsql/vvp, ) last: s
# listing
# 179105 rrcsndz.tzp 18 FileNode(/root/jmtrrrp/fmgsql/vvp, ) last: p
# list children
# FileNode(/root/jmtrrrp/fmgsql/vvp, ) file_name: rrcsndz.tzp size: 179105
# $ cd .. 7 FileNode(/root/jmtrrrp/fmgsql/vvp, ) last: .
# go to parent
# current FileNode(/root/jmtrrrp/fmgsql/vvp, )
# $ cd .. 7 FileNode(/root/jmtrrrp/fmgsql, ) last: .
# go to parent
# current FileNode(/root/jmtrrrp/fmgsql, )
# $ cd .. 7 FileNode(/root/jmtrrrp, ) last: .
# go to parent
# current FileNode(/root/jmtrrrp, )
# $ cd jssnn 10 FileNode(/root, ) last: n
# --node change
# new curr: FileNode(/root/jssnn, )
# $ ls 4 FileNode(/root/jssnn, ) last: s
# listing
# dir bphfqs 10 FileNode(/root/jssnn, ) last: s
# list children
# FileNode(/root/jssnn, ) file_name: bphfqs size: 0
# dir dbnsfp 10 FileNode(/root/jssnn, ) last: p
# list children
# FileNode(/root/jssnn, ) file_name: dbnsfp size: 0
# dir pcccp 9 FileNode(/root/jssnn, ) last: p
# list children
# FileNode(/root/jssnn, ) file_name: pcccp size: 0
# dir snr 7 FileNode(/root/jssnn, ) last: r
# list children
# FileNode(/root/jssnn, ) file_name: snr size: 0
# dir zjbvwsnv 12 FileNode(/root/jssnn, ) last: v
# list children
# FileNode(/root/jssnn, ) file_name: zjbvwsnv size: 0
# $ cd bphfqs 11 FileNode(/root/jssnn, ) last: s
# --node change
# new curr: FileNode(/root/jssnn/bphfqs, )
# $ ls 4 FileNode(/root/jssnn/bphfqs, ) last: s
# listing
# 110077 dhcrzvbr.wmn 19 FileNode(/root/jssnn/bphfqs, ) last: n
# list children
# FileNode(/root/jssnn/bphfqs, ) file_name: dhcrzvbr.wmn size: 110077
# $ cd .. 7 FileNode(/root/jssnn/bphfqs, ) last: .
# go to parent
# current FileNode(/root/jssnn/bphfqs, )
# $ cd dbnsfp 11 FileNode(/root/jssnn, ) last: p
# --node change
# new curr: FileNode(/root/jssnn/dbnsfp, )
# $ ls 4 FileNode(/root/jssnn/dbnsfp, ) last: s
# listing
# dir hgvh 8 FileNode(/root/jssnn/dbnsfp, ) last: h
# list children
# FileNode(/root/jssnn/dbnsfp, ) file_name: hgvh size: 0
# dir jtqdcmsz 12 FileNode(/root/jssnn/dbnsfp, ) last: z
# list children
# FileNode(/root/jssnn/dbnsfp, ) file_name: jtqdcmsz size: 0
# 154197 rrcsndz.tzp 18 FileNode(/root/jssnn/dbnsfp, ) last: p
# list children
# FileNode(/root/jssnn/dbnsfp, ) file_name: rrcsndz.tzp size: 154197
# $ cd hgvh 9 FileNode(/root/jssnn/dbnsfp, ) last: h
# --node change
# new curr: FileNode(/root/jssnn/dbnsfp/hgvh, )
# $ ls 4 FileNode(/root/jssnn/dbnsfp/hgvh, ) last: s
# listing
# dir qjnbg 9 FileNode(/root/jssnn/dbnsfp/hgvh, ) last: g
# list children
# FileNode(/root/jssnn/dbnsfp/hgvh, ) file_name: qjnbg size: 0
# $ cd qjnbg 10 FileNode(/root/jssnn/dbnsfp/hgvh, ) last: g
# --node change
# new curr: FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg, )
# $ ls 4 FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg, ) last: s
# listing
# dir bqzfpr 10 FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg, ) last: r
# list children
# FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg, ) file_name: bqzfpr size: 0
# $ cd bqzfpr 11 FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg, ) last: r
# --node change
# new curr: FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg/bqzfpr, )
# $ ls 4 FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg/bqzfpr, ) last: s
# listing
# 124394 wjsbsp 13 FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg/bqzfpr, ) last: p
# list children
# FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg/bqzfpr, ) file_name: wjsbsp size: 124394
# $ cd .. 7 FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg/bqzfpr, ) last: .
# go to parent
# current FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg/bqzfpr, )
# $ cd .. 7 FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg, ) last: .
# go to parent
# current FileNode(/root/jssnn/dbnsfp/hgvh/qjnbg, )
# $ cd .. 7 FileNode(/root/jssnn/dbnsfp/hgvh, ) last: .
# go to parent
# current FileNode(/root/jssnn/dbnsfp/hgvh, )
# $ cd jtqdcmsz 13 FileNode(/root/jssnn/dbnsfp, ) last: z
# --node change
# new curr: FileNode(/root/jssnn/dbnsfp/jtqdcmsz, )
# $ ls 4 FileNode(/root/jssnn/dbnsfp/jtqdcmsz, ) last: s
# listing
# 275597 dbnsfp.fpg 17 FileNode(/root/jssnn/dbnsfp/jtqdcmsz, ) last: g
# list children
# FileNode(/root/jssnn/dbnsfp/jtqdcmsz, ) file_name: dbnsfp.fpg size: 275597
# $ cd .. 7 FileNode(/root/jssnn/dbnsfp/jtqdcmsz, ) last: .
# go to parent
# current FileNode(/root/jssnn/dbnsfp/jtqdcmsz, )
# $ cd .. 7 FileNode(/root/jssnn/dbnsfp, ) last: .
# go to parent
# current FileNode(/root/jssnn/dbnsfp, )
# $ cd pcccp 10 FileNode(/root/jssnn, ) last: p
# --node change
# new curr: FileNode(/root/jssnn/pcccp, )
# $ ls 4 FileNode(/root/jssnn/pcccp, ) last: s
# listing
# dir cnbd 8 FileNode(/root/jssnn/pcccp, ) last: d
# list children
# FileNode(/root/jssnn/pcccp, ) file_name: cnbd size: 0
# 85621 cqzvwl 12 FileNode(/root/jssnn/pcccp, ) last: l
# list children
# FileNode(/root/jssnn/pcccp, ) file_name: cqzvwl size: 85621
# dir dbnsfp 10 FileNode(/root/jssnn/pcccp, ) last: p
# list children
# FileNode(/root/jssnn/pcccp, ) file_name: dbnsfp size: 0
# 114355 hbhp.cfv 15 FileNode(/root/jssnn/pcccp, ) last: v
# list children
# FileNode(/root/jssnn/pcccp, ) file_name: hbhp.cfv size: 114355
# dir mcgq 8 FileNode(/root/jssnn/pcccp, ) last: q
# list children
# FileNode(/root/jssnn/pcccp, ) file_name: mcgq size: 0
# dir pcccp 9 FileNode(/root/jssnn/pcccp, ) last: p
# list children
# FileNode(/root/jssnn/pcccp, ) file_name: pcccp size: 0
# dir qpbqqj 10 FileNode(/root/jssnn/pcccp, ) last: j
# list children
# FileNode(/root/jssnn/pcccp, ) file_name: qpbqqj size: 0
# 224038 rrcsndz.tzp 18 FileNode(/root/jssnn/pcccp, ) last: p
# list children
# FileNode(/root/jssnn/pcccp, ) file_name: rrcsndz.tzp size: 224038
# dir zcsm 8 FileNode(/root/jssnn/pcccp, ) last: m
# list children
# FileNode(/root/jssnn/pcccp, ) file_name: zcsm size: 0
# 27570 zjbvwsnv.fjt 18 FileNode(/root/jssnn/pcccp, ) last: t
# list children
# FileNode(/root/jssnn/pcccp, ) file_name: zjbvwsnv.fjt size: 27570
# $ cd cnbd 9 FileNode(/root/jssnn/pcccp, ) last: d
# --node change
# new curr: FileNode(/root/jssnn/pcccp/cnbd, )
# $ ls 4 FileNode(/root/jssnn/pcccp/cnbd, ) last: s
# listing
# dir jrbz 8 FileNode(/root/jssnn/pcccp/cnbd, ) last: z
# list children
# FileNode(/root/jssnn/pcccp/cnbd, ) file_name: jrbz size: 0
# dir pphv 8 FileNode(/root/jssnn/pcccp/cnbd, ) last: v
# list children
# FileNode(/root/jssnn/pcccp/cnbd, ) file_name: pphv size: 0
# $ cd jrbz 9 FileNode(/root/jssnn/pcccp/cnbd, ) last: z
# --node change
# new curr: FileNode(/root/jssnn/pcccp/cnbd/jrbz, )
# $ ls 4 FileNode(/root/jssnn/pcccp/cnbd/jrbz, ) last: s
# listing
# dir dwvlwfq 11 FileNode(/root/jssnn/pcccp/cnbd/jrbz, ) last: q
# list children
# FileNode(/root/jssnn/pcccp/cnbd/jrbz, ) file_name: dwvlwfq size: 0
# $ cd dwvlwfq 12 FileNode(/root/jssnn/pcccp/cnbd/jrbz, ) last: q
# --node change
# new curr: FileNode(/root/jssnn/pcccp/cnbd/jrbz/dwvlwfq, )
# $ ls 4 FileNode(/root/jssnn/pcccp/cnbd/jrbz/dwvlwfq, ) last: s
# listing
# 32237 fwclr.rnb 15 FileNode(/root/jssnn/pcccp/cnbd/jrbz/dwvlwfq, ) last: b
# list children
# FileNode(/root/jssnn/pcccp/cnbd/jrbz/dwvlwfq, ) file_name: fwclr.rnb size: 32237
# $ cd .. 7 FileNode(/root/jssnn/pcccp/cnbd/jrbz/dwvlwfq, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/cnbd/jrbz/dwvlwfq, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/cnbd/jrbz, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/cnbd/jrbz, )
# $ cd pphv 9 FileNode(/root/jssnn/pcccp/cnbd, ) last: v
# --node change
# new curr: FileNode(/root/jssnn/pcccp/cnbd/pphv, )
# $ ls 4 FileNode(/root/jssnn/pcccp/cnbd/pphv, ) last: s
# listing
# 180370 dhcrzvbr.wmn 19 FileNode(/root/jssnn/pcccp/cnbd/pphv, ) last: n
# list children
# FileNode(/root/jssnn/pcccp/cnbd/pphv, ) file_name: dhcrzvbr.wmn size: 180370
# 50154 dzvwdwl.gbt 17 FileNode(/root/jssnn/pcccp/cnbd/pphv, ) last: t
# list children
# FileNode(/root/jssnn/pcccp/cnbd/pphv, ) file_name: dzvwdwl.gbt size: 50154
# 123965 mlsv.hlw 15 FileNode(/root/jssnn/pcccp/cnbd/pphv, ) last: w
# list children
# FileNode(/root/jssnn/pcccp/cnbd/pphv, ) file_name: mlsv.hlw size: 123965
# 163116 wnhtwr.mwl 17 FileNode(/root/jssnn/pcccp/cnbd/pphv, ) last: l
# list children
# FileNode(/root/jssnn/pcccp/cnbd/pphv, ) file_name: wnhtwr.mwl size: 163116
# $ cd .. 7 FileNode(/root/jssnn/pcccp/cnbd/pphv, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/cnbd/pphv, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/cnbd, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/cnbd, )
# $ cd dbnsfp 11 FileNode(/root/jssnn/pcccp, ) last: p
# --node change
# new curr: FileNode(/root/jssnn/pcccp/dbnsfp, )
# $ ls 4 FileNode(/root/jssnn/pcccp/dbnsfp, ) last: s
# listing
# 252181 btv.mpv 14 FileNode(/root/jssnn/pcccp/dbnsfp, ) last: v
# list children
# FileNode(/root/jssnn/pcccp/dbnsfp, ) file_name: btv.mpv size: 252181
# dir hwncj 9 FileNode(/root/jssnn/pcccp/dbnsfp, ) last: j
# list children
# FileNode(/root/jssnn/pcccp/dbnsfp, ) file_name: hwncj size: 0
# dir pcccp 9 FileNode(/root/jssnn/pcccp/dbnsfp, ) last: p
# list children
# FileNode(/root/jssnn/pcccp/dbnsfp, ) file_name: pcccp size: 0
# $ cd hwncj 10 FileNode(/root/jssnn/pcccp/dbnsfp, ) last: j
# --node change
# new curr: FileNode(/root/jssnn/pcccp/dbnsfp/hwncj, )
# $ ls 4 FileNode(/root/jssnn/pcccp/dbnsfp/hwncj, ) last: s
# listing
# 51410 jbd.fcm 13 FileNode(/root/jssnn/pcccp/dbnsfp/hwncj, ) last: m
# list children
# FileNode(/root/jssnn/pcccp/dbnsfp/hwncj, ) file_name: jbd.fcm size: 51410
# $ cd .. 7 FileNode(/root/jssnn/pcccp/dbnsfp/hwncj, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/dbnsfp/hwncj, )
# $ cd pcccp 10 FileNode(/root/jssnn/pcccp/dbnsfp, ) last: p
# --node change
# new curr: FileNode(/root/jssnn/pcccp/dbnsfp/pcccp, )
# $ ls 4 FileNode(/root/jssnn/pcccp/dbnsfp/pcccp, ) last: s
# listing
# 258123 chq.jvb 14 FileNode(/root/jssnn/pcccp/dbnsfp/pcccp, ) last: b
# list children
# FileNode(/root/jssnn/pcccp/dbnsfp/pcccp, ) file_name: chq.jvb size: 258123
# $ cd .. 7 FileNode(/root/jssnn/pcccp/dbnsfp/pcccp, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/dbnsfp/pcccp, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/dbnsfp, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/dbnsfp, )
# $ cd mcgq 9 FileNode(/root/jssnn/pcccp, ) last: q
# --node change
# new curr: FileNode(/root/jssnn/pcccp/mcgq, )
# $ ls 4 FileNode(/root/jssnn/pcccp/mcgq, ) last: s
# listing
# 206506 qpbqqj.bbb 17 FileNode(/root/jssnn/pcccp/mcgq, ) last: b
# list children
# FileNode(/root/jssnn/pcccp/mcgq, ) file_name: qpbqqj.bbb size: 206506
# $ cd .. 7 FileNode(/root/jssnn/pcccp/mcgq, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/mcgq, )
# $ cd pcccp 10 FileNode(/root/jssnn/pcccp, ) last: p
# --node change
# new curr: FileNode(/root/jssnn/pcccp/pcccp, )
# $ ls 4 FileNode(/root/jssnn/pcccp/pcccp, ) last: s
# listing
# 193219 ddhtnql.hmb 18 FileNode(/root/jssnn/pcccp/pcccp, ) last: b
# list children
# FileNode(/root/jssnn/pcccp/pcccp, ) file_name: ddhtnql.hmb size: 193219
# 134114 hjbpzqzb.rwn 19 FileNode(/root/jssnn/pcccp/pcccp, ) last: n
# list children
# FileNode(/root/jssnn/pcccp/pcccp, ) file_name: hjbpzqzb.rwn size: 134114
# 108927 lznndn.nqd 17 FileNode(/root/jssnn/pcccp/pcccp, ) last: d
# list children
# FileNode(/root/jssnn/pcccp/pcccp, ) file_name: lznndn.nqd size: 108927
# 73241 ncdrv 11 FileNode(/root/jssnn/pcccp/pcccp, ) last: v
# list children
# FileNode(/root/jssnn/pcccp/pcccp, ) file_name: ncdrv size: 73241
# $ cd .. 7 FileNode(/root/jssnn/pcccp/pcccp, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/pcccp, )
# $ cd qpbqqj 11 FileNode(/root/jssnn/pcccp, ) last: j
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj, ) last: s
# listing
# dir crdt 8 FileNode(/root/jssnn/pcccp/qpbqqj, ) last: t
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj, ) file_name: crdt size: 0
# dir tgchdnc 11 FileNode(/root/jssnn/pcccp/qpbqqj, ) last: c
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj, ) file_name: tgchdnc size: 0
# $ cd crdt 9 FileNode(/root/jssnn/pcccp/qpbqqj, ) last: t
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj/crdt, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj/crdt, ) last: s
# listing
# 205710 chq.jvb 14 FileNode(/root/jssnn/pcccp/qpbqqj/crdt, ) last: b
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/crdt, ) file_name: chq.jvb size: 205710
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj/crdt, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj/crdt, )
# $ cd tgchdnc 12 FileNode(/root/jssnn/pcccp/qpbqqj, ) last: c
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) last: s
# listing
# dir bdw 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) last: w
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) file_name: bdw size: 0
# dir dpl 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) last: l
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) file_name: dpl size: 0
# dir jssnn 9 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) last: n
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) file_name: jssnn size: 0
# dir pcccp 9 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) last: p
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) file_name: pcccp size: 0
# dir plpzbm 10 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) last: m
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) file_name: plpzbm size: 0
# $ cd bdw 8 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) last: w
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/bdw, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/bdw, ) last: s
# listing
# 211300 dbnsfp.tjm 17 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/bdw, ) last: m
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/bdw, ) file_name: dbnsfp.tjm size: 211300
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/bdw, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/bdw, )
# $ cd dpl 8 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) last: l
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/dpl, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/dpl, ) last: s
# listing
# 287744 rsbjqwm 14 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/dpl, ) last: m
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/dpl, ) file_name: rsbjqwm size: 287744
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/dpl, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/dpl, )
# $ cd jssnn 10 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) last: n
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn, ) last: s
# listing
# dir jssnn 9 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn, ) last: n
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn, ) file_name: jssnn size: 0
# $ cd jssnn 10 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn, ) last: n
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn/jssnn, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn/jssnn, ) last: s
# listing
# 9644 hmjhshg.vbv 16 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn/jssnn, ) last: v
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn/jssnn, ) file_name: hmjhshg.vbv size: 9644
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn/jssnn, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn/jssnn, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/jssnn, )
# $ cd pcccp 10 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) last: p
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) last: s
# listing
# dir jssnn 9 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) last: n
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) file_name: jssnn size: 0
# 85888 pcccp.hdj 15 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) last: j
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) file_name: pcccp.hdj size: 85888
# dir qpbqqj 10 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) last: j
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) file_name: qpbqqj size: 0
# dir rmscmwtv 12 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) last: v
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) file_name: rmscmwtv size: 0
# $ cd jssnn 10 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) last: n
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/jssnn, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/jssnn, ) last: s
# listing
# 129698 crlq.lrj 15 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/jssnn, ) last: j
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/jssnn, ) file_name: crlq.lrj size: 129698
# 7499 dhcrzvbr.wmn 17 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/jssnn, ) last: n
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/jssnn, ) file_name: dhcrzvbr.wmn size: 7499
# 283607 qpbqqj.djr 17 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/jssnn, ) last: r
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/jssnn, ) file_name: qpbqqj.djr size: 283607
# 234874 wqnrhll 14 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/jssnn, ) last: l
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/jssnn, ) file_name: wqnrhll size: 234874
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/jssnn, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/jssnn, )
# $ cd qpbqqj 11 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) last: j
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/qpbqqj, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/qpbqqj, ) last: s
# listing
# 184229 qqpb.ftd 15 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/qpbqqj, ) last: d
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/qpbqqj, ) file_name: qqpb.ftd size: 184229
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/qpbqqj, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/qpbqqj, )
# $ cd rmscmwtv 13 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) last: v
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv, ) last: s
# listing
# 188048 dhcrzvbr.wmn 19 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv, ) last: n
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv, ) file_name: dhcrzvbr.wmn size: 188048
# dir jwtpgbnt 12 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv, ) last: t
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv, ) file_name: jwtpgbnt size: 0
# $ cd jwtpgbnt 13 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv, ) last: t
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv/jwtpgbnt, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv/jwtpgbnt, ) last: s
# listing
# 209946 hgg 10 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv/jwtpgbnt, ) last: g
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv/jwtpgbnt, ) file_name: hgg size: 209946
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv/jwtpgbnt, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv/jwtpgbnt, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp/rmscmwtv, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/pcccp, )
# $ cd plpzbm 11 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) last: m
# --node change
# new curr: FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/plpzbm, )
# $ ls 4 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/plpzbm, ) last: s
# listing
# 32627 tlb.qmc 13 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/plpzbm, ) last: c
# list children
# FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/plpzbm, ) file_name: tlb.qmc size: 32627
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/plpzbm, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc/plpzbm, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj/tgchdnc, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/qpbqqj, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/qpbqqj, )
# $ cd zcsm 9 FileNode(/root/jssnn/pcccp, ) last: m
# --node change
# new curr: FileNode(/root/jssnn/pcccp/zcsm, )
# $ ls 4 FileNode(/root/jssnn/pcccp/zcsm, ) last: s
# listing
# dir lczflft 11 FileNode(/root/jssnn/pcccp/zcsm, ) last: t
# list children
# FileNode(/root/jssnn/pcccp/zcsm, ) file_name: lczflft size: 0
# dir zjbvwsnv 12 FileNode(/root/jssnn/pcccp/zcsm, ) last: v
# list children
# FileNode(/root/jssnn/pcccp/zcsm, ) file_name: zjbvwsnv size: 0
# dir zmh 7 FileNode(/root/jssnn/pcccp/zcsm, ) last: h
# list children
# FileNode(/root/jssnn/pcccp/zcsm, ) file_name: zmh size: 0
# $ cd lczflft 12 FileNode(/root/jssnn/pcccp/zcsm, ) last: t
# --node change
# new curr: FileNode(/root/jssnn/pcccp/zcsm/lczflft, )
# $ ls 4 FileNode(/root/jssnn/pcccp/zcsm/lczflft, ) last: s
# listing
# 40043 dzgnvlw.scr 17 FileNode(/root/jssnn/pcccp/zcsm/lczflft, ) last: r
# list children
# FileNode(/root/jssnn/pcccp/zcsm/lczflft, ) file_name: dzgnvlw.scr size: 40043
# dir lrnb 8 FileNode(/root/jssnn/pcccp/zcsm/lczflft, ) last: b
# list children
# FileNode(/root/jssnn/pcccp/zcsm/lczflft, ) file_name: lrnb size: 0
# $ cd lrnb 9 FileNode(/root/jssnn/pcccp/zcsm/lczflft, ) last: b
# --node change
# new curr: FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb, )
# $ ls 4 FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb, ) last: s
# listing
# 109881 bjpbs 12 FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb, ) last: s
# list children
# FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb, ) file_name: bjpbs size: 109881
# dir jssnn 9 FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb, ) last: n
# list children
# FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb, ) file_name: jssnn size: 0
# 46901 npmw 10 FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb, ) last: w
# list children
# FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb, ) file_name: npmw size: 46901
# $ cd jssnn 10 FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb, ) last: n
# --node change
# new curr: FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb/jssnn, )
# $ ls 4 FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb/jssnn, ) last: s
# listing
# 9216 sgrp 9 FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb/jssnn, ) last: p
# list children
# FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb/jssnn, ) file_name: sgrp size: 9216
# $ cd .. 7 FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb/jssnn, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb/jssnn, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/zcsm/lczflft/lrnb, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/zcsm/lczflft, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/zcsm/lczflft, )
# $ cd zjbvwsnv 13 FileNode(/root/jssnn/pcccp/zcsm, ) last: v
# --node change
# new curr: FileNode(/root/jssnn/pcccp/zcsm/zjbvwsnv, )
# $ ls 4 FileNode(/root/jssnn/pcccp/zcsm/zjbvwsnv, ) last: s
# listing
# 214676 jssnn.hgn 16 FileNode(/root/jssnn/pcccp/zcsm/zjbvwsnv, ) last: n
# list children
# FileNode(/root/jssnn/pcccp/zcsm/zjbvwsnv, ) file_name: jssnn.hgn size: 214676
# $ cd .. 7 FileNode(/root/jssnn/pcccp/zcsm/zjbvwsnv, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/zcsm/zjbvwsnv, )
# $ cd zmh 8 FileNode(/root/jssnn/pcccp/zcsm, ) last: h
# --node change
# new curr: FileNode(/root/jssnn/pcccp/zcsm/zmh, )
# $ ls 4 FileNode(/root/jssnn/pcccp/zcsm/zmh, ) last: s
# listing
# dir jdt 7 FileNode(/root/jssnn/pcccp/zcsm/zmh, ) last: t
# list children
# FileNode(/root/jssnn/pcccp/zcsm/zmh, ) file_name: jdt size: 0
# dir rggpltr 11 FileNode(/root/jssnn/pcccp/zcsm/zmh, ) last: r
# list children
# FileNode(/root/jssnn/pcccp/zcsm/zmh, ) file_name: rggpltr size: 0
# $ cd jdt 8 FileNode(/root/jssnn/pcccp/zcsm/zmh, ) last: t
# --node change
# new curr: FileNode(/root/jssnn/pcccp/zcsm/zmh/jdt, )
# $ ls 4 FileNode(/root/jssnn/pcccp/zcsm/zmh/jdt, ) last: s
# listing
# 147387 jhhsv 12 FileNode(/root/jssnn/pcccp/zcsm/zmh/jdt, ) last: v
# list children
# FileNode(/root/jssnn/pcccp/zcsm/zmh/jdt, ) file_name: jhhsv size: 147387
# 90052 jssnn.wns 15 FileNode(/root/jssnn/pcccp/zcsm/zmh/jdt, ) last: s
# list children
# FileNode(/root/jssnn/pcccp/zcsm/zmh/jdt, ) file_name: jssnn.wns size: 90052
# 53105 qpbqqj.dzq 16 FileNode(/root/jssnn/pcccp/zcsm/zmh/jdt, ) last: q
# list children
# FileNode(/root/jssnn/pcccp/zcsm/zmh/jdt, ) file_name: qpbqqj.dzq size: 53105
# $ cd .. 7 FileNode(/root/jssnn/pcccp/zcsm/zmh/jdt, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/zcsm/zmh/jdt, )
# $ cd rggpltr 12 FileNode(/root/jssnn/pcccp/zcsm/zmh, ) last: r
# --node change
# new curr: FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr, )
# $ ls 4 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr, ) last: s
# listing
# 121454 dbnsfp.dzt 17 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr, ) last: t
# list children
# FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr, ) file_name: dbnsfp.dzt size: 121454
# dir gcc 7 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr, ) last: c
# list children
# FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr, ) file_name: gcc size: 0
# $ cd gcc 8 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr, ) last: c
# --node change
# new curr: FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc, )
# $ ls 4 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc, ) last: s
# listing
# dir zbqwl 9 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc, ) last: l
# list children
# FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc, ) file_name: zbqwl size: 0
# dir zjbvwsnv 12 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc, ) last: v
# list children
# FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc, ) file_name: zjbvwsnv size: 0
# $ cd zbqwl 10 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc, ) last: l
# --node change
# new curr: FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc/zbqwl, )
# $ ls 4 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc/zbqwl, ) last: s
# listing
# 260297 pcccp.jrw 16 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc/zbqwl, ) last: w
# list children
# FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc/zbqwl, ) file_name: pcccp.jrw size: 260297
# $ cd .. 7 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc/zbqwl, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc/zbqwl, )
# $ cd zjbvwsnv 13 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc, ) last: v
# --node change
# new curr: FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc/zjbvwsnv, )
# $ ls 4 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc/zjbvwsnv, ) last: s
# listing
# 248709 pcccp.tph 16 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc/zjbvwsnv, ) last: h
# list children
# FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc/zjbvwsnv, ) file_name: pcccp.tph size: 248709
# $ cd .. 7 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc/zjbvwsnv, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc/zjbvwsnv, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr/gcc, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/zcsm/zmh/rggpltr, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/zcsm/zmh, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/zcsm/zmh, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp/zcsm, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp/zcsm, )
# $ cd .. 7 FileNode(/root/jssnn/pcccp, ) last: .
# go to parent
# current FileNode(/root/jssnn/pcccp, )
# $ cd snr 8 FileNode(/root/jssnn, ) last: r
# --node change
# new curr: FileNode(/root/jssnn/snr, )
# $ ls 4 FileNode(/root/jssnn/snr, ) last: s
# listing
# 152569 chq.jvb 14 FileNode(/root/jssnn/snr, ) last: b
# list children
# FileNode(/root/jssnn/snr, ) file_name: chq.jvb size: 152569
# 1437 crlq.lrj 13 FileNode(/root/jssnn/snr, ) last: j
# list children
# FileNode(/root/jssnn/snr, ) file_name: crlq.lrj size: 1437
# $ cd .. 7 FileNode(/root/jssnn/snr, ) last: .
# go to parent
# current FileNode(/root/jssnn/snr, )
# $ cd zjbvwsnv 13 FileNode(/root/jssnn, ) last: v
# --node change
# new curr: FileNode(/root/jssnn/zjbvwsnv, )
# $ ls 4 FileNode(/root/jssnn/zjbvwsnv, ) last: s
# listing
# dir cqhb 8 FileNode(/root/jssnn/zjbvwsnv, ) last: b
# list children
# FileNode(/root/jssnn/zjbvwsnv, ) file_name: cqhb size: 0
# 53235 ghhtl.bhv 15 FileNode(/root/jssnn/zjbvwsnv, ) last: v
# list children
# FileNode(/root/jssnn/zjbvwsnv, ) file_name: ghhtl.bhv size: 53235
# 199640 npcfdw 13 FileNode(/root/jssnn/zjbvwsnv, ) last: w
# list children
# FileNode(/root/jssnn/zjbvwsnv, ) file_name: npcfdw size: 199640
# 136346 qpbqqj.lmv 17 FileNode(/root/jssnn/zjbvwsnv, ) last: v
# list children
# FileNode(/root/jssnn/zjbvwsnv, ) file_name: qpbqqj.lmv size: 136346
# dir zjbvwsnv 12 FileNode(/root/jssnn/zjbvwsnv, ) last: v
# list children
# FileNode(/root/jssnn/zjbvwsnv, ) file_name: zjbvwsnv size: 0
# $ cd cqhb 9 FileNode(/root/jssnn/zjbvwsnv, ) last: b
# --node change
# new curr: FileNode(/root/jssnn/zjbvwsnv/cqhb, )
# $ ls 4 FileNode(/root/jssnn/zjbvwsnv/cqhb, ) last: s
# listing
# 24712 sqqf 10 FileNode(/root/jssnn/zjbvwsnv/cqhb, ) last: f
# list children
# FileNode(/root/jssnn/zjbvwsnv/cqhb, ) file_name: sqqf size: 24712
# $ cd .. 7 FileNode(/root/jssnn/zjbvwsnv/cqhb, ) last: .
# go to parent
# current FileNode(/root/jssnn/zjbvwsnv/cqhb, )
# $ cd zjbvwsnv 13 FileNode(/root/jssnn/zjbvwsnv, ) last: v
# --node change
# new curr: FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, )
# $ ls 4 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) last: s
# listing
# dir gzqg 8 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) last: g
# list children
# FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) file_name: gzqg size: 0
# dir hfbfvn 10 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) last: n
# list children
# FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) file_name: hfbfvn size: 0
# dir srsphr 10 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) last: r
# list children
# FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) file_name: srsphr size: 0
# dir vgvdcvc 11 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) last: c
# list children
# FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) file_name: vgvdcvc size: 0
# $ cd gzqg 9 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) last: g
# --node change
# new curr: FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg, )
# $ ls 4 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg, ) last: s
# listing
# dir jjw 7 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg, ) last: w
# list children
# FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg, ) file_name: jjw size: 0
# $ cd jjw 8 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg, ) last: w
# --node change
# new curr: FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg/jjw, )
# $ ls 4 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg/jjw, ) last: s
# listing
# 240052 zdcjjz.pmg 17 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg/jjw, ) last: g
# list children
# FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg/jjw, ) file_name: zdcjjz.pmg size: 240052
# $ cd .. 7 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg/jjw, ) last: .
# go to parent
# current FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg/jjw, )
# $ cd .. 7 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg, ) last: .
# go to parent
# current FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/gzqg, )
# $ cd hfbfvn 11 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) last: n
# --node change
# new curr: FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/hfbfvn, )
# $ ls 4 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/hfbfvn, ) last: s
# listing
# 278190 bfgndw.pvf 17 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/hfbfvn, ) last: f
# list children
# FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/hfbfvn, ) file_name: bfgndw.pvf size: 278190
# $ cd .. 7 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/hfbfvn, ) last: .
# go to parent
# current FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/hfbfvn, )
# $ cd srsphr 11 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) last: r
# --node change
# new curr: FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/srsphr, )
# $ ls 4 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/srsphr, ) last: s
# listing
# 42591 zjbvwsnv.hgh 18 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/srsphr, ) last: h
# list children
# FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/srsphr, ) file_name: zjbvwsnv.hgh size: 42591
# $ cd .. 7 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/srsphr, ) last: .
# go to parent
# current FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/srsphr, )
# $ cd vgvdcvc 12 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) last: c
# --node change
# new curr: FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/vgvdcvc, )
# $ ls 4 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/vgvdcvc, ) last: s
# listing
# 120322 rrcsndz.tzp 18 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/vgvdcvc, ) last: p
# list children
# FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/vgvdcvc, ) file_name: rrcsndz.tzp size: 120322
# $ cd .. 7 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/vgvdcvc, ) last: .
# go to parent
# current FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv/vgvdcvc, )
# $ cd .. 7 FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, ) last: .
# go to parent
# current FileNode(/root/jssnn/zjbvwsnv/zjbvwsnv, )
# $ cd .. 7 FileNode(/root/jssnn/zjbvwsnv, ) last: .
# go to parent
# current FileNode(/root/jssnn/zjbvwsnv, )
# $ cd .. 7 FileNode(/root/jssnn, ) last: .
# go to parent
# current FileNode(/root/jssnn, )
# $ cd lbrmb 10 FileNode(/root, ) last: b
# --node change
# new curr: FileNode(/root/lbrmb, )
# $ ls 4 FileNode(/root/lbrmb, ) last: s
# listing
# dir bjhpdj 10 FileNode(/root/lbrmb, ) last: j
# list children
# FileNode(/root/lbrmb, ) file_name: bjhpdj size: 0
# 42241 crlq.lrj 14 FileNode(/root/lbrmb, ) last: j
# list children
# FileNode(/root/lbrmb, ) file_name: crlq.lrj size: 42241
# dir dbnsfp 10 FileNode(/root/lbrmb, ) last: p
# list children
# FileNode(/root/lbrmb, ) file_name: dbnsfp size: 0
# 244610 dhcrzvbr.wmn 19 FileNode(/root/lbrmb, ) last: n
# list children
# FileNode(/root/lbrmb, ) file_name: dhcrzvbr.wmn size: 244610
# dir hppb 8 FileNode(/root/lbrmb, ) last: b
# list children
# FileNode(/root/lbrmb, ) file_name: hppb size: 0
# dir mcnzs 9 FileNode(/root/lbrmb, ) last: s
# list children
# FileNode(/root/lbrmb, ) file_name: mcnzs size: 0
# dir npntsr 10 FileNode(/root/lbrmb, ) last: r
# list children
# FileNode(/root/lbrmb, ) file_name: npntsr size: 0
# 13625 tpjpcsgp.dlz 18 FileNode(/root/lbrmb, ) last: z
# list children
# FileNode(/root/lbrmb, ) file_name: tpjpcsgp.dlz size: 13625
# 219424 vvpbt.zvf 16 FileNode(/root/lbrmb, ) last: f
# list children
# FileNode(/root/lbrmb, ) file_name: vvpbt.zvf size: 219424
# dir zjbvwsnv 12 FileNode(/root/lbrmb, ) last: v
# list children
# FileNode(/root/lbrmb, ) file_name: zjbvwsnv size: 0
# 191467 zjbvwsnv.htn 19 FileNode(/root/lbrmb, ) last: n
# list children
# FileNode(/root/lbrmb, ) file_name: zjbvwsnv.htn size: 191467
# $ cd bjhpdj 11 FileNode(/root/lbrmb, ) last: j
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj, ) last: s
# listing
# dir bqjvst 10 FileNode(/root/lbrmb/bjhpdj, ) last: t
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: bqjvst size: 0
# 204722 dbnsfp 13 FileNode(/root/lbrmb/bjhpdj, ) last: p
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: dbnsfp size: 204722
# dir dhltrqqq 12 FileNode(/root/lbrmb/bjhpdj, ) last: q
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: dhltrqqq size: 0
# 226082 dmdqcjp 14 FileNode(/root/lbrmb/bjhpdj, ) last: p
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: dmdqcjp size: 226082
# dir fcqwgzp 11 FileNode(/root/lbrmb/bjhpdj, ) last: p
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: fcqwgzp size: 0
# dir jssnn 9 FileNode(/root/lbrmb/bjhpdj, ) last: n
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: jssnn size: 0
# 6453 jssnn.ndh 14 FileNode(/root/lbrmb/bjhpdj, ) last: h
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: jssnn.ndh size: 6453
# 23799 jssnn.zqn 15 FileNode(/root/lbrmb/bjhpdj, ) last: n
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: jssnn.zqn size: 23799
# dir nwglfhpl 12 FileNode(/root/lbrmb/bjhpdj, ) last: l
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: nwglfhpl size: 0
# dir pcccp 9 FileNode(/root/lbrmb/bjhpdj, ) last: p
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: pcccp size: 0
# dir pdnj 8 FileNode(/root/lbrmb/bjhpdj, ) last: j
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: pdnj size: 0
# 269246 shzqns.nws 17 FileNode(/root/lbrmb/bjhpdj, ) last: s
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: shzqns.nws size: 269246
# dir sjstqlcb 12 FileNode(/root/lbrmb/bjhpdj, ) last: b
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: sjstqlcb size: 0
# dir zssln 9 FileNode(/root/lbrmb/bjhpdj, ) last: n
# list children
# FileNode(/root/lbrmb/bjhpdj, ) file_name: zssln size: 0
# $ cd bqjvst 11 FileNode(/root/lbrmb/bjhpdj, ) last: t
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj/bqjvst, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj/bqjvst, ) last: s
# listing
# 202793 dbnsfp.pjj 17 FileNode(/root/lbrmb/bjhpdj/bqjvst, ) last: j
# list children
# FileNode(/root/lbrmb/bjhpdj/bqjvst, ) file_name: dbnsfp.pjj size: 202793
# 259783 jssnn 12 FileNode(/root/lbrmb/bjhpdj/bqjvst, ) last: n
# list children
# FileNode(/root/lbrmb/bjhpdj/bqjvst, ) file_name: jssnn size: 259783
# dir rbvbhnvs 12 FileNode(/root/lbrmb/bjhpdj/bqjvst, ) last: s
# list children
# FileNode(/root/lbrmb/bjhpdj/bqjvst, ) file_name: rbvbhnvs size: 0
# 30683 rvddnjmb.tlz 18 FileNode(/root/lbrmb/bjhpdj/bqjvst, ) last: z
# list children
# FileNode(/root/lbrmb/bjhpdj/bqjvst, ) file_name: rvddnjmb.tlz size: 30683
# dir tzhslnv 11 FileNode(/root/lbrmb/bjhpdj/bqjvst, ) last: v
# list children
# FileNode(/root/lbrmb/bjhpdj/bqjvst, ) file_name: tzhslnv size: 0
# $ cd rbvbhnvs 13 FileNode(/root/lbrmb/bjhpdj/bqjvst, ) last: s
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj/bqjvst/rbvbhnvs, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj/bqjvst/rbvbhnvs, ) last: s
# listing
# 86934 vrtrf.htt 15 FileNode(/root/lbrmb/bjhpdj/bqjvst/rbvbhnvs, ) last: t
# list children
# FileNode(/root/lbrmb/bjhpdj/bqjvst/rbvbhnvs, ) file_name: vrtrf.htt size: 86934
# $ cd .. 7 FileNode(/root/lbrmb/bjhpdj/bqjvst/rbvbhnvs, ) last: .
# go to parent
# current FileNode(/root/lbrmb/bjhpdj/bqjvst/rbvbhnvs, )
# $ cd tzhslnv 12 FileNode(/root/lbrmb/bjhpdj/bqjvst, ) last: v
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj/bqjvst/tzhslnv, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj/bqjvst/tzhslnv, ) last: s
# listing
# 76278 mghcwdlr.tsc 18 FileNode(/root/lbrmb/bjhpdj/bqjvst/tzhslnv, ) last: c
# list children
# FileNode(/root/lbrmb/bjhpdj/bqjvst/tzhslnv, ) file_name: mghcwdlr.tsc size: 76278
# $ cd .. 7 FileNode(/root/lbrmb/bjhpdj/bqjvst/tzhslnv, ) last: .
# go to parent
# current FileNode(/root/lbrmb/bjhpdj/bqjvst/tzhslnv, )
# $ cd .. 7 FileNode(/root/lbrmb/bjhpdj/bqjvst, ) last: .
# go to parent
# current FileNode(/root/lbrmb/bjhpdj/bqjvst, )
# $ cd dhltrqqq 13 FileNode(/root/lbrmb/bjhpdj, ) last: q
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj/dhltrqqq, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) last: s
# listing
# dir mfd 7 FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) last: d
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) file_name: mfd size: 0
# dir pcccp 9 FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) last: p
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) file_name: pcccp size: 0
# dir smmb 8 FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) last: b
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) file_name: smmb size: 0
# 251164 wsdnsgtt.lhr 19 FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) last: r
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) file_name: wsdnsgtt.lhr size: 251164
# 191876 zvr.bbz 14 FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) last: z
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) file_name: zvr.bbz size: 191876
# $ cd mfd 8 FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) last: d
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj/dhltrqqq/mfd, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/mfd, ) last: s
# listing
# 51017 crlq.lrj 14 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/mfd, ) last: j
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/mfd, ) file_name: crlq.lrj size: 51017
# 99213 rjtbnnnq.hgd 18 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/mfd, ) last: d
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/mfd, ) file_name: rjtbnnnq.hgd size: 99213
# $ cd .. 7 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/mfd, ) last: .
# go to parent
# current FileNode(/root/lbrmb/bjhpdj/dhltrqqq/mfd, )
# $ cd pcccp 10 FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) last: p
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp, ) last: s
# listing
# 160487 dhcrzvbr.wmn 19 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp, ) last: n
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp, ) file_name: dhcrzvbr.wmn size: 160487
# dir nhdrnthj 12 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp, ) last: j
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp, ) file_name: nhdrnthj size: 0
# dir qpbqqj 10 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp, ) last: j
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp, ) file_name: qpbqqj size: 0
# $ cd nhdrnthj 13 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp, ) last: j
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, ) last: s
# listing
# 181291 bbn.wtm 14 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, ) last: m
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, ) file_name: bbn.wtm size: 181291
# 186551 fnw.tnn 14 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, ) last: n
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, ) file_name: fnw.tnn size: 186551
# 23622 rrcsndz.tzp 17 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, ) last: p
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, ) file_name: rrcsndz.tzp size: 23622
# dir zjbvwsnv 12 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, ) last: v
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, ) file_name: zjbvwsnv size: 0
# $ cd zjbvwsnv 13 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, ) last: v
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj/zjbvwsnv, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj/zjbvwsnv, ) last: s
# listing
# 227547 dhcrzvbr.wmn 19 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj/zjbvwsnv, ) last: n
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj/zjbvwsnv, ) file_name: dhcrzvbr.wmn size: 227547
# $ cd .. 7 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj/zjbvwsnv, ) last: .
# go to parent
# current FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj/zjbvwsnv, )
# $ cd .. 7 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, ) last: .
# go to parent
# current FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/nhdrnthj, )
# $ cd qpbqqj 11 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp, ) last: j
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj, ) last: s
# listing
# 212353 crlq.lrj 15 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj, ) last: j
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj, ) file_name: crlq.lrj size: 212353
# 170195 dhcrzvbr.wmn 19 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj, ) last: n
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj, ) file_name: dhcrzvbr.wmn size: 170195
# dir ttvp 8 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj, ) last: p
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj, ) file_name: ttvp size: 0
# $ cd ttvp 9 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj, ) last: p
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj/ttvp, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj/ttvp, ) last: s
# listing
# 185994 tgjcfgjv 15 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj/ttvp, ) last: v
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj/ttvp, ) file_name: tgjcfgjv size: 185994
# $ cd .. 7 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj/ttvp, ) last: .
# go to parent
# current FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj/ttvp, )
# $ cd .. 7 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj, ) last: .
# go to parent
# current FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp/qpbqqj, )
# $ cd .. 7 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp, ) last: .
# go to parent
# current FileNode(/root/lbrmb/bjhpdj/dhltrqqq/pcccp, )
# $ cd smmb 9 FileNode(/root/lbrmb/bjhpdj/dhltrqqq, ) last: b
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) last: s
# listing
# dir dbnsfp 10 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) last: p
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) file_name: dbnsfp size: 0
# 85354 dbnsfp.zpn 16 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) last: n
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) file_name: dbnsfp.zpn size: 85354
# 80665 dfmmjbm.rnr 17 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) last: r
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) file_name: dfmmjbm.rnr size: 80665
# 135989 dhcrzvbr.wmn 19 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) last: n
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) file_name: dhcrzvbr.wmn size: 135989
# 93718 lrbzr.nfs 15 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) last: s
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) file_name: lrbzr.nfs size: 93718
# dir mjpfnfns 12 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) last: s
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) file_name: mjpfnfns size: 0
# dir nsdpfnhb 12 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) last: b
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) file_name: nsdpfnhb size: 0
# dir pmnssvd 11 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) last: d
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) file_name: pmnssvd size: 0
# 32270 qpbqqj.vtd 16 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) last: d
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) file_name: qpbqqj.vtd size: 32270
# $ cd dbnsfp 11 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb, ) last: p
# --node change
# new curr: FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb/dbnsfp, )
# $ ls 4 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb/dbnsfp, ) last: s
# listing
# 31796 gzs.rgv 13 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb/dbnsfp, ) last: v
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb/dbnsfp, ) file_name: gzs.rgv size: 31796
# 64506 vbjncw.bpz 16 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb/dbnsfp, ) last: z
# list children
# FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb/dbnsfp, ) file_name: vbjncw.bpz size: 64506
# 181659 vjlfrdp.tqh 18 FileNode(/root/lbrmb/bjhpdj/dhltrqqq/smmb/dbnsfp, ) last: h
# ...
# dir fhhlbdlz 12 FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) last: z
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) file_name: fhhlbdlz size: 0
# dir gstjw 9 FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) last: w
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) file_name: gstjw size: 0
# dir qpbqqj 10 FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) last: j
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) file_name: qpbqqj size: 0
# dir stgb 8 FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) last: b
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) file_name: stgb size: 0
# $ cd czm 8 FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) last: m
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm, ) last: s
# listing
# dir jssnn 9 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm, ) last: n
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm, ) file_name: jssnn size: 0
# $ cd jssnn 10 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm, ) last: n
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, ) last: s
# listing
# 162335 chq.jvb 14 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, ) last: b
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, ) file_name: chq.jvb size: 162335
# 30099 mfdgdw 12 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, ) last: w
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, ) file_name: mfdgdw size: 30099
# 96389 pcdsd.wmw 15 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, ) last: w
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, ) file_name: pcdsd.wmw size: 96389
# 251423 tmz.lcb 14 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, ) last: b
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, ) file_name: tmz.lcb size: 251423
# 205979 vpltdt.gtv 17 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, ) last: v
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, ) file_name: vpltdt.gtv size: 205979
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm/jssnn, )
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/czm, )
# $ cd fhhlbdlz 13 FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) last: z
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, ) last: s
# listing
# dir qpbqqj 10 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, ) last: j
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, ) file_name: qpbqqj size: 0
# dir vdjs 8 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, ) last: s
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, ) file_name: vdjs size: 0
# dir zgz 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, ) last: z
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, ) file_name: zgz size: 0
# $ cd qpbqqj 11 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, ) last: j
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/qpbqqj, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/qpbqqj, ) last: s
# listing
# 285561 chq.jvb 14 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/qpbqqj, ) last: b
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/qpbqqj, ) file_name: chq.jvb size: 285561
# 263924 lbqcfdrs 15 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/qpbqqj, ) last: s
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/qpbqqj, ) file_name: lbqcfdrs size: 263924
# 138854 pcccp.dtn 16 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/qpbqqj, ) last: n
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/qpbqqj, ) file_name: pcccp.dtn size: 138854
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/qpbqqj, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/qpbqqj, )
# $ cd vdjs 9 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, ) last: s
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/vdjs, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/vdjs, ) last: s
# listing
# 32688 chq.jvb 13 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/vdjs, ) last: b
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/vdjs, ) file_name: chq.jvb size: 32688
# 223233 tbn.blt 14 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/vdjs, ) last: t
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/vdjs, ) file_name: tbn.blt size: 223233
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/vdjs, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/vdjs, )
# $ cd zgz 8 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, ) last: z
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/zgz, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/zgz, ) last: s
# listing
# 92804 bqltmv.wzb 16 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/zgz, ) last: b
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/zgz, ) file_name: bqltmv.wzb size: 92804
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/zgz, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz/zgz, )
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/fhhlbdlz, )
# $ cd gstjw 10 FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) last: w
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/gstjw, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/gstjw, ) last: s
# listing
# 151784 fvfszzzn.cbh 19 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/gstjw, ) last: h
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/gstjw, ) file_name: fvfszzzn.cbh size: 151784
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/gstjw, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/gstjw, )
# $ cd qpbqqj 11 FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) last: j
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj, ) last: s
# listing
# dir blztqf 10 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj, ) last: f
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj, ) file_name: blztqf size: 0
# dir plgnh 9 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj, ) last: h
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj, ) file_name: plgnh size: 0
# $ cd blztqf 11 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj, ) last: f
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/blztqf, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/blztqf, ) last: s
# listing
# 195097 wlvmtz 13 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/blztqf, ) last: z
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/blztqf, ) file_name: wlvmtz size: 195097
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/blztqf, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/blztqf, )
# $ cd plgnh 10 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj, ) last: h
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) last: s
# listing
# dir dbnsfp 10 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) last: p
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) file_name: dbnsfp size: 0
# 246221 dhcrzvbr.wmn 19 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) last: n
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) file_name: dhcrzvbr.wmn size: 246221
# 271121 jhwmmzls.mhw 19 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) last: w
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) file_name: jhwmmzls.mhw size: 271121
# 170162 pcccp.dpp 16 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) last: p
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) file_name: pcccp.dpp size: 170162
# 37872 qpbqqj 12 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) last: j
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) file_name: qpbqqj size: 37872
# $ cd dbnsfp 11 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) last: p
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp, ) last: s
# listing
# dir dhpnr 9 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp, ) last: r
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp, ) file_name: dhpnr size: 0
# $ cd dhpnr 10 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp, ) last: r
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp/dhpnr, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp/dhpnr, ) last: s
# listing
# 152837 pcccp 12 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp/dhpnr, ) last: p
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp/dhpnr, ) file_name: pcccp size: 152837
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp/dhpnr, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp/dhpnr, )
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh/dbnsfp, )
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj/plgnh, )
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/qpbqqj, )
# $ cd stgb 9 FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) last: b
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/dgrrl/stgb, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/stgb, ) last: s
# listing
# 248436 vjlfrdp.tqh 18 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/stgb, ) last: h
# list children
# FileNode(/root/lbrmb/zjbvwsnv/dgrrl/stgb, ) file_name: vjlfrdp.tqh size: 248436
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl/stgb, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl/stgb, )
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/dgrrl, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/dgrrl, )
# $ cd phggn 10 FileNode(/root/lbrmb/zjbvwsnv, ) last: n
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/phggn, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/phggn, ) last: s
# listing
# 284602 dhcrzvbr.wmn 19 FileNode(/root/lbrmb/zjbvwsnv/phggn, ) last: n
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn, ) file_name: dhcrzvbr.wmn size: 284602
# dir lctr 8 FileNode(/root/lbrmb/zjbvwsnv/phggn, ) last: r
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn, ) file_name: lctr size: 0
# dir rjmc 8 FileNode(/root/lbrmb/zjbvwsnv/phggn, ) last: c
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn, ) file_name: rjmc size: 0
# 66651 rrcsndz.tzp 17 FileNode(/root/lbrmb/zjbvwsnv/phggn, ) last: p
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn, ) file_name: rrcsndz.tzp size: 66651
# 117525 vth.fgw 14 FileNode(/root/lbrmb/zjbvwsnv/phggn, ) last: w
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn, ) file_name: vth.fgw size: 117525
# 156877 wcqnjzbq.dgf 19 FileNode(/root/lbrmb/zjbvwsnv/phggn, ) last: f
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn, ) file_name: wcqnjzbq.dgf size: 156877
# 7803 zpsrzclh.bzw 17 FileNode(/root/lbrmb/zjbvwsnv/phggn, ) last: w
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn, ) file_name: zpsrzclh.bzw size: 7803
# $ cd lctr 9 FileNode(/root/lbrmb/zjbvwsnv/phggn, ) last: r
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) last: s
# listing
# 212339 jssnn.whp 16 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) last: p
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) file_name: jssnn.whp size: 212339
# dir jzhcqb 10 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) last: b
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) file_name: jzhcqb size: 0
# 99974 pcccp.zhs 15 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) last: s
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) file_name: pcccp.zhs size: 99974
# 111354 pmc 10 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) last: c
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) file_name: pmc size: 111354
# 104899 vjlfrdp.tqh 18 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) last: h
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) file_name: vjlfrdp.tqh size: 104899
# 93496 zhwmbw 12 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) last: w
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) file_name: zhwmbw size: 93496
# $ cd jzhcqb 11 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) last: b
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb, ) last: s
# listing
# dir zjbvwsnv 12 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb, ) last: v
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb, ) file_name: zjbvwsnv size: 0
# $ cd zjbvwsnv 13 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb, ) last: v
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb/zjbvwsnv, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb/zjbvwsnv, ) last: s
# listing
# 146807 rbrg 11 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb/zjbvwsnv, ) last: g
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb/zjbvwsnv, ) file_name: rbrg size: 146807
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb/zjbvwsnv, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb/zjbvwsnv, )
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr/jzhcqb, )
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/phggn/lctr, )
# $ cd rjmc 9 FileNode(/root/lbrmb/zjbvwsnv/phggn, ) last: c
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) last: s
# listing
# dir fvbmsc 10 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) last: c
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) file_name: fvbmsc size: 0
# 139747 glwmr.lrg 16 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) last: g
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) file_name: glwmr.lrg size: 139747
# dir gvnnz 9 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) last: z
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) file_name: gvnnz size: 0
# 102023 tbj.qmz 14 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) last: z
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) file_name: tbj.qmz size: 102023
# dir vsztsjfh 12 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) last: h
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) file_name: vsztsjfh size: 0
# $ cd fvbmsc 11 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) last: c
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/fvbmsc, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/fvbmsc, ) last: s
# listing
# 136838 vpvbz.qtw 16 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/fvbmsc, ) last: w
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/fvbmsc, ) file_name: vpvbz.qtw size: 136838
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/fvbmsc, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/fvbmsc, )
# $ cd gvnnz 10 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) last: z
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/gvnnz, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/gvnnz, ) last: s
# listing
# 95498 zjbvwsnv 14 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/gvnnz, ) last: v
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/gvnnz, ) file_name: zjbvwsnv size: 95498
# $ cd .. 7 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/gvnnz, ) last: .
# go to parent
# current FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/gvnnz, )
# $ cd vsztsjfh 13 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc, ) last: h
# --node change
# new curr: FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/vsztsjfh, )
# $ ls 4 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/vsztsjfh, ) last: s
# listing
# 215479 ffwlcrwb 15 FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/vsztsjfh, ) last: b
# list children
# FileNode(/root/lbrmb/zjbvwsnv/phggn/rjmc/vsztsjfh, ) file_name: ffwlcrwb size: 215479

# %%
def find_sum(tree):
    nodes=findall(tree,lambda node:node.size<=100000 and node.type=='dir')
    arr=[node.size for node in nodes]
    return subarray.findMaxSubarraySum(arr,len(arr),100000),sum(arr)
find_sum(tree)
# Out:
# (95437, 95437)

# %%
find_sum(tree2)
# Out:
# (98974, 1086293)

# %% [markdown]
# ### Free up space

# %%
nodes=findall(tree,lambda node:node.type=='dir')
arr=[node.size for node in nodes]
arr
# Out:
# [48381165, 94853, 584, 24933642]

# %%
total=0
size_dict={}
for node in nodes:
    if node.name=='root':
        size_dict['root']=node.size
        size_dict['unused']=70000000-node.size
        size_dict['size_to_delete']=30000000-size_dict['unused']
    else: 
        total+=node.size
size_dict['used']=total


size_dict
# Out:
# {'root': 48381165,
#  'unused': 21618835,
#  'size_to_delete': 8381165,
#  'used': 25029079}

# %%
min([x for x in arr if x>=size_dict['size_to_delete']])
# Out:
# 24933642

# %%
def delete_directory(tree):
    nodes=findall(tree,lambda node:node.type=='dir')
    total=0
    size_dict={}
    for node in nodes:
        if node.name=='root':
            size_dict['root']=node.size
            size_dict['unused']=70000000-node.size
            size_dict['size_to_delete']=30000000-size_dict['unused']
        else: 
            total+=node.size
    size_dict['used']=total

    arr=[node.size for node in nodes if node.size>=size_dict['size_to_delete']]

    return min(arr)

delete_directory(tree)
# Out:
# 24933642

# %%
delete_directory(tree2)
# Out:
# 366028
